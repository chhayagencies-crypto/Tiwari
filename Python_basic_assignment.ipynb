# %% [markdown]
# Question 1 : What is Python and why is it widely used in Data Analytics? Mention any three reasons.
#
# Ans1. Python is a programming language which is widely used and very populardue to easy syntax and easy readibility.
# 1. Is beginner friendly even for those who are not from tech background that is the reason it is very famous for data analysis.
# 2. it has powerful liabraries like panda, numpy, seaborn and mataplotlib which is very useful in data analystics field.
# 3. it can handle large data set very easily.
#
#
#
# due to easy syntax it
#
# Question 2 : Explain the difference between List and Tuple in Python.
#
# Ans2. the main difference between list &  Tupple are below
#
# List:  it is mutable, ordered and allows duplicates and also mixed data type ( Boolean, text,int etc), it uses []
#
# Tuple:  it allows duplicates , ordered but not mutable.tuple basically uses with ()
#
# Question 3 : What is a function in Python? Why are functions useful?
#
# Ans3. A function in Python is a reusable block of code used to perform a specific task. Functions are useful because they improve code reusability, readability, and make debugging easier.
#
# Question 4 : Write a Python program to take a user's name as input and print a greeting message.
#
# Ans4. below is the code
#
# name=input("enter your name:")
# print("Hello", name)
#
#
# Question 5 : Write a Python program to check whether a number is even or odd using conditional
# statements.
#
# Ans5. PFB
#
# num=int(input("enter a number:"))
# if num%2 == 0:
#     print("EVEN")
# else:
#     print("ODD")
#
#
#
# Question 6 : Write a program to print numbers from 1 to 10 using a loop.
#
# Ans6. for i in range(1,11):
#     print(i)
#
#
# Question 7 : Create a list of five numbers and print the maximum number from the list.
#
# Ans7.  PFB
#
# numbers = [12, 45, 7, 89, 23]
#
# print("Maximum number is:", max(numbers))
#
# Question 8 : Write a Python program to remove duplicate values from a list using a set.
#
# Ans8.
#
# numbers = [1, 2, 2, 3, 4, 4, 5]
#
# unique_numbers = list(set(numbers))
#
# print("List without duplicates:", unique_numbers)
#
#
# Question 9 : Write a function that returns the square of a number.
#
# def square(num):
#     return num * num
#
# print(square(5))
#
# Question 10 : Write a Python program to count how many times a number appears in a list
#
# Example List
# [2,3,4,2,5,2]
#
# Ans 10
#
# numbers = [2, 3, 4, 2, 5, 2]
#
# count_2 = numbers.count(2)
#
# print("Number 2 appears:", count_2, "times")
