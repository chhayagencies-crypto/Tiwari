# %% [markdown]
# Note : Create the following dummy table in MySQL Workbench using CREATE FUNCTION-
#
# ![image.png](data:image/png;base64,...)
#
# We will create the table by below SQL Code
#
#
# ![image.png](data:image/png;base64,...)
#
# Q1. Show employees working in either the ‘IT’ or ‘HR’ departments.
#
# A1.  SELECT EmpID, EmpName, Department, City, Salary, HireDate
#  FROM Employees1
#  WHERE Department IN ('IT', 'HR');
#
#
# Q2. Retrieve employees whose department is in ‘Sales’, ‘IT’, or ‘Finance’
#
# A2. SELECT EmpID, EmpName, Department, City, Salary, HireDate FROM Company_Employees WHERE Department IN ('Sales', 'IT', 'Finance');
#
#
# Q3.   Display employees whose salary is between ₹50,000 and ₹70,000
#
# A3. SELECT EmpID, EmpName, Department, City, Salary, HireDate FROM Company_Employees WHERE Salary BETWEEN 50000 AND 70000;
#
#
# Q4.  List employees whose names start with the letter ‘A’.
#
# A4.  SELECT EmpID, EmpName, Department, City, Salary, HireDate FROM Company_Employees WHERE EmpName LIKE 'A%';
#
# Q5.  Find employees whose names contain the substring ‘an’
#
# A5.
#
# Q6.  Show employees who are from ‘Delhi’ or ‘Mumbai’ and earn more than ₹55,000
#
# A6. SELECT EmpID, EmpName, Department, City, Salary, HireDate FROM Company_Employees WHERE EmpName LIKE '%an%';
#
# Q7.  Display all employees except those from the ‘HR’ department
#
# A7. SELECT EmpID, EmpName, Department, City, Salary, HireDate FROM Company_Employees WHERE Department <> 'HR'
#
# Q8.Get all employees hired between 2019 and 2022, ordered by HireDate (oldest first)
#
# A8.SELECT EmpID, EmpName, Department, City, Salary, HireDate FROM Company_Employees WHERE HireDate BETWEEN '2019-01-01' AND '2022-12-31' ORDER BY HireDate
