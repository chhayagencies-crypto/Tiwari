# %% [markdown]
# Q1. Write a formula to check if the marks in cell are greater than or equal to 40. If yes,"Pass" return , otherwise "fail"
#
# ![image.png](data:image/png;base64,...)
#
# Ans 1:  =IF(B2>=40,"Pass","Failed")  = Pass
#
#
# Q2.  company gives a bonus  if sales are above 40,000 and attendance is greater than or equal to 90%. Write a formula to calculate whether the employee will get a bonus or not .
#
# ![image.png](data:image/png;base64,...)
#
# Ans2. toget the both satisfactory criateria we will use and function PFB
#
# =AND(J2>40000,K2>=90) only Arjun is eligible as we received true vale rest are not eligible PFB
#
# ![image.png](data:image/png;base64,...)
#
# Q3. Write a nested IF formula:
# If marks in B2 are ≥ 90 →"A" , ≥ 75 →"B" , ≥ 50 →"C" , otherwise "Fail" .
#
# ![image.png](data:image/png;base64,...)
#
# Ans3:  We will use below
#
# =IF(B2>=90,"A",IF(B2>=75,"B",IF(B2>=50,"C","Fail")))
#
# ![image.png](data:image/png;base64,...)
#
# Q4.Find the Department of Employee ID = E103. Also explain which LOOKUP function is used and why?
#
# Ans4.  as per the above data and required look up value we can use V lookup to get the answer as the lookup return is right side of Look up value.
#
# =VLOOKUP(I15,I12:K16,3,0) here we are getting Department as
#
# NOTE#  not loked the array as single value we need to identify.
#
# ![image.png](data:image/png;base64,...)
#
#
#
# Q5. A company has set the following commission structure for its sales team:
#
# ![image.png](data:image/png;base64,...)
#
#
# If a salesperson achieves sales of ₹45,000, use the VLOOKUP function to determine the commission rate
# applicable.
#
# Ans5. here 45000 not in the table , if we use the vlookup hence we can not get the exact match, ₹45,000 falls between ₹20,000 and ₹50,000, the applicable commission rate is 10% if we used approximate match PFb
#
# =VLOOKUP(S4,$P$4:$Q$7,2,1)
#
#
# Q6.The HR department maintains the following leave records of employees:onus or not
# ![image.png](data:image/png;base64,...)
#
# Write an IF function to check whether an employee has Exceeded their allowed leave balance.
#
# If Leaves Taken > Allowed Leaves, display "Exceeded".
#
# Otherwise, display "OK".
#
# ANS6.  Here i used If function and used below formula
#
# =IF(Q12>$R$12,"Exceeded","OK")
#
# Please find the output
#
# ![image.png](data:image/png;base64,...)
#
# Q7.  Find the salary of EmpID = E105 using INDEX-MATCH Function.
#
# ![image.png](data:image/png;base64,...)
#
# Ans7.  we will use indec- match function to identify the salary E105 of below  formula i used and Salary is 72000
#
# =INDEX(R19:R22,MATCH(Q20,Q19:Q22,0))
#
#
# EmpIDs are in range: R19:R22 in my excel sheet
# Salaries are in range: Q20:Q22
# Lookup value (E105) is in cell Q20
#
# Explanation
#
# 1. MATCH(Q20,Q19:Q22,0): finds the row number where EmpID = E105
# 2. INDEX(R19:R22....): returns the salary from that row in the Salary column
#
# Q8.  Use the XLOOKUP function to find the Department of the employee with Emp ID = E303.
#
# ![image.png](data:image/png;base64,...)
#
# Ans8. the department is "IT" for Emoplyee ID E303. Please find below Formula used as per my excel sheet
#
# =XLOOKUP(B3,B2:B5,C2:C5,"Not in data",0,1)  below is the screenshot
#
# ![image.png](data:image/png;base64,...)
