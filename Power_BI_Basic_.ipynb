# %% [markdown]
# Question 1 : What is Power BI and why is it used in businesses?
#
# Ans 1.  Power Bi is a business analytic tools through which we can visulise , clean etc live data as well as static data and use insights for business desicions.
#
# it is not just a pretty chart making through the power Bi instead of guts feeling anyone can get the decision making by using this
# it can pull data from multiple sources like ms excel, google sheet , sql.
#
# it is basically a very simple tool like excel but much more than excel in terms of visulaisation and cleaning the data.
#
#
#
# Ans 2.  The main three component of Power BI
#
# A. Power Bi desktop: used for visulisation, it is free of cost to use in desktops.
#
# B. Power BIServices: here you can publish your created report
#
# C.Power BI Mobile:   here you may use to viewing reports and dashboard.
#
#
#
# Question 3 : Explain the Power BI workflow.
#
# A3.  below is the power BI worklflow
#
# DATA prepration ( get & transform data)> Report Creation( viualisation)>Publishing ( Share) > distribution and consumption ( Viewing )
#
# Question 4 : List any four data cleaning tasks that can be performed in Power Query
#
# A4.  Power BI can do multiple tasks which is related to cleaning four are below
#
# 1.  Remove rows & columns
# 2.  Changing data type
# 3.  Spliting & merging columns
# 4.  relacing values & handeling Null.
#
# Using Data Set
#
# Question 5 : Write step by step instructions to load the above dataset.
#
# Ans 5.  These are the steps to load this data
#
# 1. Open Power BI desktop
# 2. Click on blank Report
# 3. in the HOME tab click on click on connect data from multiple Sources and then choose excel
# 4.Select the downloaded data set
# 5 click on Load
#
# Question 6 : Define Data View, Report View, and Model View. Explain the purpose of each view.
#
# A6.  Report View :  this is basically a canvas where we create charts , pivots etc for visulisation.
#
# DATA View: A view that allows you to inspect the actual data inside your tables after it has been loaded into the model.
#
# Model view :  A visual diagram showing all the tables in your dataset and the lines (relationships) connecting them.
#
#
# Question 7 : Discuss the different data sources that Power BI supports.
#
# A7.  this is the most powerfull tool where you can connect data from multiple sources Some of below
#
# File based : EXCEL/google sheets, CSV /text
# Relational data bases: SQL Server, My SQL etc.
# Clod base : MS AZURE AWS ETC
#
#
# Question 8 : Split Owner Name to create two new columns as First Name and Last Name
#
# A8.  once select data clicked on Transform
#
# > Selected Owner_name  Column
# > Clicked on transform Tab > Split Column> By delimeter(Space) > Split at each occurence of the delimiterselected OK
