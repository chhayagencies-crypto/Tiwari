# %% [markdown]
# Q1: Understanding Central Tendency (Easy)
# A bakery tracks the daily sales of muffins (in dozens) over a week: [10, 12, 11, 15, 14, 13, 12].
# What is the most representative value of their weekly sales, and why?
#
#
# A1.  the mean value should be the most represantative value in this as there were no outliers in the data set hence mean will provide best represantation of overall distribution without bias.
#
# = 12.43
#
# Q2: Mean in Real Life (Easy)
# A teacher records the marks of her students in a short quiz: [12, 15, 14, 16, 18, 20, 19].
# What is the mean score, and what does it tell us about the class’s performance?
#
#
# A2. the mean score of the class is 16.2857 , it tell us all the scores of the students are not so mar from avaerage score hence the class performance is upto the mark.
#
# Q3: Mode in Real Life (Easy)
# A store records the shoe sizes sold in one day: [7, 8, 9, 8, 8, 10, 7, 9].
# What is the mode, and why is this information useful for the store manager?
#
# A3. the mode of the above data set is 8. with the use of Mode or the value 8 shoes manager manage their inventory as soe size 8 is most selleing or most demanding shoe size as per previous recoreded sale.
#
# Medium Level
#
#
# Q4: Median in Real Life (Medium)
# A car dealer notes the prices of used cars: [$8,000, $9,500, $10,200, $11,000, $50,000].
# Why is the median a better measure than the mean in this case? Calculate the median.
#
#
# A4.  from above data set below are the mean= 17740 & median= 10200.
# in this daat set $50,000 is a outlier if we prefer mean instead of median we will  not get the actual insight from this.
# hence we will consider median over mean to avoide destortion from extreme values(outliers).
#
# Q5: Dispersion Introduction (Medium)
# A student times how long it takes to finish a puzzle each day: [25, 30, 27, 35, 40].
# What does the range tell us about the variation in the student’s puzzle-solving time?
#
# A5. here the time range is = 40-25= 15 min.
# it showes the student is not consistant the shortest time he is taking 25 min while the longest time is 40 min while the window to solve the puzzle is 15 min.
#
#
#
# Q6: Range in Action (Medium)
# A farmer records the weekly weight of harvested apples (kg): [100, 105, 98, 110, 120].
# Find the range. How can this help the farmer in planning his packaging?
#
# A6. here the range is 120-98=22Kg
# through this farmer should be prepare for resources and planing to meet this fluctuation.
#
# Q7: Variance for Decision-Making (Medium)
# Two delivery companies track delivery delays (in minutes).
# Company A: variance = 6
# Company B: variance = 15
# Which company is more consistent, and why?
#
# A7. as we know variance measures how spreadout the data from mean.Company A is smaller variance vs Company B
# here Company A is more relaiable in term of delivery delays as it is more closer to mean as compare to Company B.
#
# Hard Level
# Q8: Standard Deviation in Context (Hard)
# A finance student compares the daily price fluctuations of two cryptocurrencies.
# Coin A: standard deviation = $30
# Coin B: standard deviation = $120
# Which coin is riskier to invest in, and why?
#
# A8. Standard Deviation shows the fluctuation of value from its mean, in coin B fluctuation is more which means the prices ranges fluctuates more hence Coin B will be more riskier to invest.
#
# Q9: Combining Measures (Hard)
# A family records their monthly electricity usage (in kWh): [400, 420, 390, 450, 410]
# Find the mean and standard deviation. What do these values together tell you about the family’s energy use
# pattern?
#
#
# A9. here the mean is 414 and std deviation is 23.02.
#
# it shows there is slight fluctuation around the mean hence we can say electricity consumtion is stable from above data and std deviation and mean.
#
# Q10: Practical Application (Hard)
# A basketball player’s points in 8 games are recorded: [15, 18, 20, 22, 25, 17, 19, 21].
# Find the mean, median, mode, range, and standard deviation. What insights can these measures provide
# about the player’s scoring performance?
#
# A10. PFB
#
# Mean=19.625
# median=19.5
# Mode= NA
# Range= 10
# Std deviation = 3.113
#
# Conclusion: player is a consistant player having average of approx 20 poitns with slight variation.
