# %% [markdown]
# Question 1: A die is rolled. What is the probability of getting:
# (a) An even number
# (b) A number greater than 4
#
# A1. (a)  probability to getting even no is
#
#      P(even)= 3/6= 0.5
#
#      (b)  probablility To get no greater than 4 is
#
#       P= 2/6  = 0.33
#
#
# Question 2: In a class of 50 students:
# 20 like Mathematics (M)
# 15 like Science (S)
# 5 like both subjects
# What is the probability that a student chosen at random likes Mathematics or Science?
#
# A2. Students likes Maths or Science = 20 +15-5= 30
#
# probability P= 30/50 = 0.6
#
#
# Question 3: A bag has 3 red and 2 blue balls. If one ball is drawn randomly and is red, what is the probability that the next ball is also red (without replacement)?
#
#
# A3. Total balls =
# 3
#  red +
# 2
#  blue = 5 balls.
#
#  After removing 1 red ball red balls left = 3-1=2  & blue balls left =2
#  so the total balls is 4 now
#
#  So probability is P = 2/4=0.5
#
#
# Question 4: The population of a school is divided into 60% boys and 40% girls. If you want equal representation
# of both genders in the sample, which method should you use: Simple Random Sampling or Stratified Sampling?
# Why?
#
# A4. the startified menthod will use in this case for equal representation of boys and girls
#
# reason :- here the boys 7 girls population is not same hence firstly we categories it in two groups boys and girls than we choose equal no of girls 7 boys for sampling which can be possible in startified menthod of sampling not in simple random collection as boys are higher than girls if we use simple random there is a probability to get higher no of boys which is not asking in the q.
#
#
# Question 5: The average height of 1000 students = 160 cm. A sample of 100 students shows an average height
# = 158 cm.
# Find the sampling error.
#
# A5. Sampling error =  population avg height - Sample avg height
#                    = 160-158= 2 cm
#
#
# Question 6: The population mean salary is ₹50,000 with σ = ₹5,000. If we take a sample of 100 employees, what
# is the standard error of the mean (SEM)?
#
# A6.  Standard error of mean(SEM)= standard deviation/square root of sample
#                                 =5000/square root of 100
#                                 = 5000/10
#                                 =500
#
#
# Question 7: In a group of 100 students:
# 40 like Cricket (C)
# 30 like Football (F)
# 10 like both Cricket and Football
# Find the probability that a student likes at least one sport.
#
#
# A7.  people who likes at least one sports is =  40 +30-10= 60
#
#
# probability =60/100= .6
#
#
# Question 8: From a deck of 52 cards, two cards are drawn without replacement. What is the probability that both are Aces
#
#
# A8. first Ace probability P1= 4/52= 1/13
#     second Ace probability p2= 3/51= 1/17
#
#     probability that both cards are ace is = 1/13 * 1/17= 1/221
#
#
#
# Question 9: A factory produces bulbs with 2% defective rate. If 5 bulbs are chosen at random, what is the
# probability that all are non-defective?
#
# A9. probability of non defective = 1 - 0.2 = 0.98
#
#    hence probability of 5 bulbs non defective = (0.98)^5
#
#
# Question 10: Differentiate between discrete and continuous random variables with examples
#
#
# A10.   the simple deferance between discrete vs continuous is if you are able to count its descrete , if you measure its continuous random varibales
#
# ex of descrete_  no of students, coins etc
# ex of descrete-  height , weight , time etc
